# %% [markdown]
# <a href="https://colab.research.google.com/github/abhithale/PANDAS/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(
    '/content/BigBasket Products.csv',
    engine='python',
    encoding='latin1',
    on_bad_lines='skip'
)# copy the file path and pest it

# %%
df.head(5)
# Out:
#    index                                            product  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg
# 1      2                              Water Bottle - Orange
# 2      3                     Brass Angle Deep - Plain, No.2
# 3      4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      5                 Creme Soft Soap - For Hands & Body
#
#                  category           sub_category              brand  \
# 0        Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 1  Kitchen, Garden & Pets  Storage & Accessories         Mastercook
# 2    Cleaning & Household            Pooja Needs                Trm
# 3    Cleaning & Household   Bins & Bathroom Ware             Nakoda
# 4        Beauty & Hygiene       Bath & Hand Wash              Nivea
#
#    sale_price  market_price                      type  rating  \
# 0       220.0         220.0          Hair Oil & Serum     4.1
# 1       180.0         180.0    Water & Fridge Bottles     2.3
# ...

# %%
df.tail(1)
# Out:
#        index                         product          category  \
# 27554  27555  United Dreams Go Far Deodorant  Beauty & Hygiene
#
#          sub_category                       brand  sale_price  market_price  \
# 27554  Men's Grooming  United Colors Of Benetton       214.53         390.0
#
#                    type  rating  \
# 27554  Men's Deodorants     4.5
#
#                                              description
# 27554  The new mens fragrance from the United Dreams ...

# %%
df.head(-1)
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27549  27550                               Papad - Garlic Disco
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
#
#                      category              sub_category              brand  \
# 0            Beauty & Hygiene                 Hair Care  Sri Sri Ayurveda
# ...

# %%
df.shape
# Out:
# (27555, 10)

# %%
num_rows = df.shape[0]
num_rows
# Out:
# 27555

# %%
df.info() # summery of file like colums , rows , datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27555 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18929 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %%
df.describe() # returns only int and float values that are stoer in file
# Out:
#              index    sale_price  market_price        rating
# count  27555.00000  27555.000000  27555.000000  18929.000000
# mean   13778.00000    322.514808    382.056664      3.943410
# std     7954.58767    486.263116    581.730717      0.739063
# min        1.00000      2.450000      3.000000      1.000000
# 25%     6889.50000     95.000000    100.000000      3.700000
# 50%    13778.00000    190.000000    220.000000      4.100000
# 75%    20666.50000    359.000000    425.000000      4.300000
# max    27555.00000  12500.000000  12500.000000      5.000000

# %%
df[['index' , 'sale_price']].describe() # to load colums that we want to work on
# Out:
#              index    sale_price
# count  27555.00000  27555.000000
# mean   13778.00000    322.514808
# std     7954.58767    486.263116
# min        1.00000      2.450000
# 25%     6889.50000     95.000000
# 50%    13778.00000    190.000000
# 75%    20666.50000    359.000000
# max    27555.00000  12500.000000

# %%
df[['rating']].describe()
# Out:
#              rating
# count  18929.000000
# mean       3.943410
# std        0.739063
# min        1.000000
# 25%        3.700000
# 50%        4.100000
# 75%        4.300000
# max        5.000000

# %%
df.columns
# Out:
# Index(['index', 'product', 'category', 'sub_category', 'brand', 'sale_price',
#        'market_price', 'type', 'rating', 'description'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=27555, step=1)

# %%
df.columns.tolist() # print columns name in form of list
# Out:
# ['index',
#  'product',
#  'category',
#  'sub_category',
#  'brand',
#  'sale_price',
#  'market_price',
#  'type',
#  'rating',
#  'description']

# %%
len(df.index)
# Out:
# 27555

# %%
df.index
# Out:
# RangeIndex(start=0, stop=27555, step=1)

# %% [markdown]
# #.dtypes in pandas
# - comman Data Type in pandas:
# - object - Text/string data
# - int64 - integer number
# - float64 - Decimal number
# - datetime64 - Dates and time

# %%
df.dtypes
# Out:
# index             int64
# product          object
# category         object
# sub_category     object
# brand            object
# sale_price      float64
# market_price    float64
# type             object
# rating          float64
# description      object
# dtype: object

# %%
df.dtypes.value_counts() # retunrs in which column which type of data have stored
# Out:
# object     6
# float64    3
# int64      1
# Name: count, dtype: int64

# %%
df['product']
# Out:
# 0                   Garlic Oil - Vegetarian Capsule 500 mg
# 1                                    Water Bottle - Orange
# 2                           Brass Angle Deep - Plain, No.2
# 3        Cereal Flip Lid Container/Storage Jar - Assort...
# 4                       Creme Soft Soap - For Hands & Body
#                                ...
# 27550           Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                             Rosemary
# 27552                         Peri-Peri Sweet Potato Chips
# 27553                            Green Tea - Pure Original
# 27554                       United Dreams Go Far Deodorant
# Name: product, Length: 27555, dtype: object

# %%
df_1 = df[['product','rating','index']]
df_1
# Out:
#                                                  product  rating  index
# 0                 Garlic Oil - Vegetarian Capsule 500 mg     4.1      1
# 1                                  Water Bottle - Orange     2.3      2
# 2                         Brass Angle Deep - Plain, No.2     3.4      3
# 3      Cereal Flip Lid Container/Storage Jar - Assort...     3.7      4
# 4                     Creme Soft Soap - For Hands & Body     4.4      5
# ...                                                  ...     ...    ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic     3.9  27551
# 27551                                           Rosemary     4.0  27552
# 27552                       Peri-Peri Sweet Potato Chips     3.8  27553
# 27553                          Green Tea - Pure Original     4.2  27554
# 27554                     United Dreams Go Far Deodorant     4.5  27555
#
# [27555 rows x 3 columns]

# %%
df.select_dtypes(include=['int64', 'float64']).columns
# Out:
# Index(['index', 'sale_price', 'market_price', 'rating'], dtype='object')

# %% [markdown]
# #practice

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/BigBasket Products.csv')

# %%
df.shape
# Out:
# (27555, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27555 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18929 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %%
df.head()
# Out:
#    index                                            product  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg
# 1      2                              Water Bottle - Orange
# 2      3                     Brass Angle Deep - Plain, No.2
# 3      4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      5                 Creme Soft Soap - For Hands & Body
#
#                  category           sub_category              brand  \
# 0        Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 1  Kitchen, Garden & Pets  Storage & Accessories         Mastercook
# 2    Cleaning & Household            Pooja Needs                Trm
# 3    Cleaning & Household   Bins & Bathroom Ware             Nakoda
# 4        Beauty & Hygiene       Bath & Hand Wash              Nivea
#
#    sale_price  market_price                      type  rating  \
# 0       220.0         220.0          Hair Oil & Serum     4.1
# 1       180.0         180.0    Water & Fridge Bottles     2.3
# ...

# %%
df.tail()
# Out:
#        index                                     product  \
# 27550  27551  Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                    Rosemary
# 27552  27553                Peri-Peri Sweet Potato Chips
# 27553  27554                   Green Tea - Pure Original
# 27554  27555              United Dreams Go Far Deodorant
#
#                    category              sub_category  \
# 27550      Beauty & Hygiene         Fragrances & Deos
# 27551  Gourmet & World Food    Cooking & Baking Needs
# 27552  Gourmet & World Food  Snacks, Dry Fruits, Nuts
# 27553             Beverages                       Tea
# 27554      Beauty & Hygiene            Men's Grooming
#
#                             brand  sale_price  market_price  \
# 27550                      Layerr      199.20         249.0
# 27551                    Puramate       67.50          75.0
# 27552                      FabBox      200.00         200.0
# ...

# %%
df.columns
# Out:
# Index(['index', 'product', 'category', 'sub_category', 'brand', 'sale_price',
#        'market_price', 'type', 'rating', 'description'],
#       dtype='object')

# %%
df.sort_values('sale_price' , ascending = True)
# Out:
#        index                                            product  \
# 26976  26977                                       Curry Leaves
# 21312  21313                                              Serum
# 14184  14185                  Tomato - Local, Organically Grown
# 27490  27491                     50-50 Timepass Salted Biscuits
# 22178  22179                       Tiger Elaichi Cream Biscuits
# ...      ...                                                ...
# 2781    2782                             Extra Virgin Olive Oil
# 23082  23083  Gas Stove-4 Burner Royale Plus Schott Glass, B...
# 12669  12670                   Epilator SE9-9961 Legs-Body-Face
# 21761  21762      Pet Food - N&D Team Breeder Puppy Top Farmina
# 25301  25302                                    Bravura Clipper
#
#                      category                 sub_category      brand  \
# 26976     Fruits & Vegetables           Herbs & Seasonings     Fresho
# ...

# %%
df.rename(columns={'sale_price' : 'sale_price1'})
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df.isnull().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         0
# market_price       0
# type               0
# rating          8626
# description      115
# dtype: int64

# %%
df['rating'].isnull().sum()
# Out:
# np.int64(8626)

# %%
df['product'].isnull().sum()
# Out:
# np.int64(1)

# %%
df.dropna() # if one value are missing then all row will be deleted
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df.dropna(how='all') # here if the row is all empty then it will delete the all row otherwise it will keep at is
# how = 'all' - it select only that roa who have all null values
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df.dropna(axis = 1)
# Out:
#        index                category              sub_category  sale_price  \
# 0          1        Beauty & Hygiene                 Hair Care      220.00
# 1          2  Kitchen, Garden & Pets     Storage & Accessories      180.00
# 2          3    Cleaning & Household               Pooja Needs      119.00
# 3          4    Cleaning & Household      Bins & Bathroom Ware      149.00
# 4          5        Beauty & Hygiene          Bath & Hand Wash      162.00
# ...      ...                     ...                       ...         ...
# 27550  27551        Beauty & Hygiene         Fragrances & Deos      199.20
# 27551  27552    Gourmet & World Food    Cooking & Baking Needs       67.50
# 27552  27553    Gourmet & World Food  Snacks, Dry Fruits, Nuts      200.00
# 27553  27554               Beverages                       Tea      396.00
# 27554  27555        Beauty & Hygiene            Men's Grooming      214.53
#
#        market_price                      type
# ...

# %%
df.fillna(method = 'ffill') # null ko null ke pehele ke index ki value assigne krta hai
# Out:
# /tmp/ipython-input-155/3504009942.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'ffill') # null ko null ke pehele ke index ki value assigne krta hai
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# ...

# %%
df.fillna(method = 'bfill') # null ke niche ki value ko null ko bhi assign kr dega
# Out:
# /tmp/ipython-input-155/462884640.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'bfill') # null ke niche ki value ko null ko bhi assign kr dega
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# ...

# %%
df[df['brand'] == 'Nivea']
# Out:
#        index                                            product  \
# 4          5                 Creme Soft Soap - For Hands & Body
# 318      319    Milk Delights Face Wash With Honey For Dry Skin
# 412      413  Original Care Lip Balm For 24h Moisture With S...
# 2538    2539  Extra Whitening Cell Repair Body Lotion - SPF ...
# 2582    2583  Whitening Smooth Skin Women Deodorant Roll On ...
# ...      ...                                                ...
# 26911  26912            Body Wash - Frangipani & Oil Shower Gel
# 26992  26993   Milk Delights Face Wash With Besan For Oily Skin
# 27080  27081  Women Deodorant Roll On - Protect & Care, Non-...
# 27153  27154  Cherry Shine Lip Balm - 24h Moisture With Natu...
# 27167  27168  Milk Delights Women Face Wash With Turmeric Fo...
#
#                category       sub_category  brand  sale_price  market_price  \
# 4      Beauty & Hygiene   Bath & Hand Wash  Nivea      162.00         162.0
# ...

# %% [markdown]
# **loc[]*** **iloc[]**

# %%
import pandas as pd
import numpy as np


data = {
    'roll no ' : [101,102,103],
    'name' : ["Abhishek","janhavi","sakshi"],
    'marks' : [90,45,80]

}


df = pd.DataFrame(data , index = ['x','y','z'])

# %%
df
# Out:
#    roll no       name  marks
# x       101  Abhishek     90
# y       102   janhavi     45
# z       103    sakshi     80

# %%
df.loc['x'] # we assigen index name and accesing it with help of loc[]
# Out:
# roll no          101
# name        Abhishek
# marks             90
# Name: x, dtype: object

# %%
df.iloc[1] # use to acces with inbuilt indexing
# Out:
# roll no         102
# name        janhavi
# marks            45
# Name: y, dtype: object
